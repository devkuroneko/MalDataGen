# %%
import pandas as pd
import numpy as np

train_x = pd.read_csv('../Datasets/converted/train_x.csv')
test_x = pd.read_csv('../Datasets/converted/test_x.csv')
valid_x = pd.read_csv('../Datasets/converted/valid_x.csv')

# %%
train_x.describe()

# %%
test_x.describe()

# %%
valid_x.describe()
